# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %%
# Import all required modules
import datetime as dt 
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# For training
from sklearn import linear_model
from sklearn.model_selection import train_test_split

# For evaluation
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics import r2_score

# %%
finances = pd.read_csv('diaries_transactions_all.csv')

# %%
finances.shape
# Out:
# (483949, 58)

# %%
# columns
finances.columns
# Out:
# Index(['hh_ids', 'unique_hhs', 'first_trx_date_hh', 'last_trx_date_hh',
#        'tot_hh_daysofobs', 'tot_hh_monthsofobs', 'interview_designation',
#        'int_date', 'int_month', 'int_year', 'int_yr_mo', 'first_int_date',
#        'account_ids', 'unique_accnts', 'm_ids_owner', 'unique_hm_owner',
#        'account_bsheet_desig', 'account_startclose_balance', 'account_formal',
#        'account_liquid', 'first_trx_date_acc', 'last_trx_date_acc',
#        'tot_acc_daysofobs', 'tot_acc_monthsofobs', 'trx_id', 'm_ids_trx',
#        'trx_date', 'trx_month', 'trx_year', 'trx_yr_mo', 'trx_dq_round',
#        'trx_stdtime_days_hh', 'trx_stdtime_mnths_hh', 'trx_stdtime_days_acc',
#        'trx_stdtime_mnths_acc', 'trx_class_code', 'trx_class_desc',
#        'trx_family_code', 'trx_family_desc', 'trx_type_code', 'trx_type_desc',
#        'trx_prx_purpose', 'trx_prx_purpose_fd', 'trx_fee',
#        'trx_bsheet_direction', 'trx_mode_code', 'trx_mode_desc',
#        'trx_place_incommunity', 'trx_distance_km', 'trx_outlet',
#        'trx_direction', 'trx_value_kes', 'trx_value_usd', 'ddd_gift',
#        'trx_inkind_units', 'trx_inkind_value_usd', 'trx_inkind_value_kes',
#        'trx_stdtime_mnths_hh_nr'],
#       dtype='object')

# %%
finances.describe()
# Out:
#        unique_hhs  tot_hh_daysofobs  tot_hh_monthsofobs      int_month  \
# count       298.0     483949.000000       483949.000000  483949.000000
# mean          1.0        394.805825           13.125895       6.426041
# std           0.0         32.657529            1.141561       3.204513
# min           1.0        214.000000            7.000000       1.000000
# 25%           1.0        375.000000           12.000000       4.000000
# 50%           1.0        391.000000           13.000000       7.000000
# 75%           1.0        413.000000           14.000000       9.000000
# max           1.0        501.000000           17.000000      12.000000
#
#             int_year  unique_accnts  unique_hm_owner  tot_acc_daysofobs  \
# count  483949.000000         9546.0            670.0      483949.000000
# mean     2012.847717            1.0              1.0         421.460920
# std         0.359490            0.0              0.0         118.927981
# min      2012.000000            1.0              1.0           0.000000
# 25%      2013.000000            1.0              1.0         358.000000
# 50%      2013.000000            1.0              1.0         502.000000
# 75%      2013.000000            1.0              1.0         502.000000
# max      2015.000000            1.0              1.0         502.000000
#
#        tot_acc_monthsofobs        trx_id  ...       trx_fee  trx_mode_code  \
# count        483949.000000  4.839490e+05  ...  77070.000000  476292.000000
# mean             14.157174  7.068031e+16  ...      0.067679       2.199067
# std               4.169955  1.964200e+16  ...      0.251195       3.461173
# min               0.000000  3.413549e+16  ...      0.000000       1.000000
# 25%              12.000000  5.713807e+16  ...      0.000000       1.000000
# 50%              17.000000  6.213598e+16  ...      0.000000       1.000000
# 75%              17.000000  8.913662e+16  ...      0.000000       1.000000
# max              17.000000  1.121385e+17  ...      1.000000      19.000000
#
#        trx_place_incommunity  trx_distance_km  trx_value_kes  trx_value_usd  \
# count          457703.000000    457498.000000   4.834300e+05  483430.000000
# mean                0.869527         6.824379   6.547228e+02       7.702621
# std                 0.336824        79.340121   5.453241e+03      64.155778
# min                 0.000000         0.000000  -2.595000e+04    -305.294100
# 25%                 1.000000         0.000000   2.000000e+01       0.235294
# 50%                 1.000000         0.000000   5.000000e+01       0.588235
# 75%                 1.000000         0.000000   2.300000e+02       2.705882
# max                 1.000000     14317.670000   1.200000e+06   14117.650000
#
#             ddd_gift  trx_inkind_value_usd  trx_inkind_value_kes  \
# count  483949.000000          12798.000000          12798.000000
# mean        0.003350              3.616619            307.412564
# std         0.057778             28.127688           2390.853350
# min         0.000000              0.000000              0.000000
# 25%         0.000000              0.000000              0.000000
# 50%         0.000000              0.470588             40.000000
# 75%         0.000000              1.529412            130.000000
# max         1.000000           1529.412000         130000.000000
#
#        trx_stdtime_mnths_hh_nr
# count            483949.000000
# mean                  7.336331
# std                   3.766231
# min                   0.000000
# 25%                   4.275862
# 50%                   7.620690
# 75%                  10.482760
# max                  17.275860
#
# [8 rows x 28 columns]

# %%
finances.head()
# Out:
#     hh_ids  unique_hhs first_trx_date_hh last_trx_date_hh  tot_hh_daysofobs  \
# 0  KELDL02         NaN         03sep2012        02oct2013               394
# 1  KVIHC16         NaN         24sep2012        19sep2013               360
# 2  KELDK21         NaN         20sep2012        22oct2013               397
# 3  KMOMT22         NaN         21sep2012        01nov2013               406
# 4  KMOMT32         NaN         20sep2012        18oct2013               393
#
#    tot_hh_monthsofobs interview_designation   int_date  int_month  int_year  \
# 0                  13  04=Diaries Interview  02oct2013         10      2013
# 1                  12  04=Diaries Interview  22apr2013          4      2013
# 2                  13  04=Diaries Interview  02oct2013         10      2013
# 3                  14  04=Diaries Interview  21feb2013          2      2013
# 4                  13  04=Diaries Interview  02may2013          5      2013
#
#    ... trx_distance_km trx_outlet trx_direction  trx_value_kes trx_value_usd  \
# 0  ...             NaN        NaN           NaN            0.0      0.000000
# 1  ...             NaN        NaN       Outflow          100.0      1.176471
# 2  ...             NaN        NaN           NaN            0.0      0.000000
# 3  ...             NaN        NaN        Inflow          710.0      8.352942
# 4  ...             NaN        NaN       Outflow          100.0      1.176471
#
#    ddd_gift trx_inkind_units trx_inkind_value_usd trx_inkind_value_kes  \
# 0         0              NaN                  NaN                  NaN
# 1         0              NaN                  NaN                  NaN
# 2         0              NaN                  NaN                  NaN
# 3         0              NaN                  NaN                  NaN
# 4         0              NaN                  NaN                  NaN
#
#   trx_stdtime_mnths_hh_nr
# 0               13.586210
# 1                7.206897
# 2               13.000000
# 3                4.793103
# 4                6.517241
#
# [5 rows x 58 columns]

# %%
finances.tail()
# Out:
#          hh_ids  unique_hhs first_trx_date_hh last_trx_date_hh  \
# 483944  KZIMA08         NaN         21mar2013        21oct2013
# 483945  KZIMA08         NaN         21mar2013        21oct2013
# 483946  KZIMA08         NaN         21mar2013        21oct2013
# 483947  KMOMK03         NaN         07sep2012        25oct2013
# 483948  KMOMM11         NaN         17aug2012        04oct2013
#
#         tot_hh_daysofobs  tot_hh_monthsofobs interview_designation   int_date  \
# 483944               214                   7  04=Diaries Interview  02aug2013
# 483945               214                   7  04=Diaries Interview  04oct2013
# 483946               214                   7  04=Diaries Interview  21aug2013
# 483947               413                  14  04=Diaries Interview  01aug2013
# 483948               413                  14  04=Diaries Interview  01nov2012
#
#         int_month  int_year  ... trx_distance_km  \
# 483944          8      2013  ...        0.378316
# 483945         10      2013  ...        0.378316
# 483946          8      2013  ...        0.378316
# 483947          8      2013  ...       74.572090
# 483948         11      2012  ...        1.590156
#
#                                            trx_outlet trx_direction  \
# 483944                                            NaN       Outflow
# 483945                                            NaN       Outflow
# 483946               08=Restaurant, bar, hotel, cyber       Outflow
# 483947  10=Institution (clinic, school, church, etc.)       Outflow
# 483948                                            NaN       Outflow
#
#         trx_value_kes trx_value_usd  ddd_gift trx_inkind_units  \
# 483944           30.0      0.352941         0              NaN
# 483945          100.0      1.176471         0              NaN
# 483946           50.0      0.588235         0              NaN
# 483947         1650.0     19.411760         0              NaN
# 483948          100.0      1.176471         0              NaN
#
#        trx_inkind_value_usd trx_inkind_value_kes trx_stdtime_mnths_hh_nr
# 483944                  NaN                  NaN                4.586207
# 483945                  NaN                  NaN                6.448276
# 483946                  NaN                  NaN                4.827586
# 483947                  NaN                  NaN               10.965520
# 483948                  NaN                  NaN                2.413793
#
# [5 rows x 58 columns]

# %%
finances['int_year'].value_counts(ascending=True)
# Out:
# 2015         4
# 2014        22
# 2012     73727
# 2013    410196
# Name: int_year, dtype: int64

# %%
finances.groupby('int_year').size().plot();
